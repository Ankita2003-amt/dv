# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankita2003-amt/dv/blob/main/dv_07_dec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.DataFrame({"Name":['Rita','Mita','Sita','Nita','gita'],"Roll_No":[1,2,3,4,5],"Marks":[23,65,43,21,89]})
print(data)
# Out:
#    Name  Roll_No  Marks
# 0  Rita        1     23
# 1  Mita        2     65
# 2  Sita        3     43
# 3  Nita        4     21
# 4  gita        5     89

# %%
data.describe()
# Out:
#         Roll_No      Marks
# count  5.000000   5.000000
# mean   3.000000  48.200000
# std    1.581139  28.934409
# min    1.000000  21.000000
# 25%    2.000000  23.000000
# 50%    3.000000  43.000000
# 75%    4.000000  65.000000
# max    5.000000  89.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Roll_No'].plot(kind='hist', bins=20, title='Roll_No')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Marks'].plot(kind='hist', bins=20, title='Marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Roll_No', y='Marks', s=32, alpha=.8)
# ...

# %%
data.describe(include="object")
# Out:
#         Name
# count      5
# unique     5
# top     Rita
# freq       1

# %%
data.nunique()
# Out:
# Name       4
# Roll_No    5
# Marks      5
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Name       0
# Roll_No    0
# Marks      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data["Name"].value_counts()
# Out:
# Rita    1
# Mita    1
# Sita    1
# Nita    1
# gita    1
# Name: Name, dtype: int64

# %%
data["Roll_No"].value_counts()
# Out:
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: Roll_No, dtype: int64

# %%
data["Marks"].value_counts()
# Out:
# 23    1
# 65    1
# 43    1
# 21    1
# 89    1
# Name: Marks, dtype: int64

# %%
data["Marks"].mean()
# Out:
# 48.2

# %%
data["Marks"].var()
# Out:
# 837.2

# %%
correlation=data.corr()
# Out:
# <ipython-input-57-7f2487af4b08>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=data.corr()

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True,fmt='.1f',cmap="coolwarm")
# Out:
# <Axes: >
